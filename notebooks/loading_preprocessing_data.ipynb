# %% [markdown]
# <a href="https://colab.research.google.com/github/laibaa1209/spoken-language-classifier/blob/main/notebooks/loading_preprocessing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# connecting GPU
import torch
torch.cuda.is_available(), torch.cuda.get_device_name(0)
# Out:
# (True, 'Tesla T4')

# %%
# downloading libraries
# !pip install datasets transformers torchaudio librosa soundfile moviepy scikit-learn
# !apt-get install ffmpeg # video to audio extraction
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
